# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from PyEMD import EMD, Visualisation
# %matplotlib inline

# %%
x = np.arange(0,10,0.001)
y1 = 4 + np.sin(2*np.pi * x + 1) + np.cos(2*np.pi*2*x +2)
y2 = 10 * np.sin(2 * np.pi * 50 * x +np.pi*3/4)

g1 = y1 * y2
g2 = y1 + y2
plt.figure(figsize=(32,10))
plt.plot(y2, color='black')
plt.plot(g1, color='red')
# plt.plot(g2, color='blue')
plt.show()
